# %%
## Data Wrangling

# %%
import os
import pandas as pd
pd.set_option('display.max_rows', 50)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 50)
import numpy as np
from pandas import Series, DataFrame

# %%
df = pd.read_csv('datasets/dataset-06-storms.csv',low_memory=False)

# %%
df
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0
# ...         ...                 ...          ...       ...     ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0
#
#           COUNTYNAME STATE      EVTYPE  BGN_RANGE BGN_AZI BGN_LOCATI  \
# 0             MOBILE    AL     TORNADO        0.0     NaN        NaN
# ...

# %%
df2 = df[ ['COUNTYNAME','STATE','EVTYPE','FATALITIES', 'INJURIES','PROPDMG', 'CROPDMG','PROPDMGEXP','CROPDMGEXP'] ]

# %%
df2
# Out:
#                                   COUNTYNAME STATE          EVTYPE  \
# 0                                     MOBILE    AL         TORNADO
# 1                                    BALDWIN    AL         TORNADO
# 2                                    FAYETTE    AL         TORNADO
# 3                                    MADISON    AL         TORNADO
# 4                                    CULLMAN    AL         TORNADO
# 5                                 LAUDERDALE    AL         TORNADO
# 6                                     BLOUNT    AL         TORNADO
# 7                                 TALLAPOOSA    AL         TORNADO
# 8                                 TUSCALOOSA    AL         TORNADO
# 9                                    FAYETTE    AL         TORNADO
# 10                                   CULLMAN    AL         TORNADO
# 11                                    BLOUNT    AL         TORNADO
# 12                                 JEFFERSON    AL         TORNADO
# ...

# %%
len(np.sort(df2.EVTYPE.unique()))
# Out:
# 985

# %%
len(df2[['PROPDMGEXP']].groupby('PROPDMGEXP').count())
# Out:
# 18

# %%
df3 = df2[(df2.FATALITIES >= 1) | (df2.INJURIES >=1) | (df2.PROPDMG >=1) | (df2.CROPDMG >=1)]

# %%
df2.shape[0]
# Out:
# 902297

# %%
df3.shape[0]
# Out:
# 239063

# %%
len(df3.EVTYPE.unique())
# Out:
# 474

# %%
df3[['STATE','EVTYPE','FATALITIES']].groupby(['STATE','EVTYPE']).sum()
# Out:
#                               FATALITIES
# STATE EVTYPE
# AK    AVALANCHE                     33.0
#       BLIZZARD                       7.0
#       BREAKUP FLOODING               0.0
#       COASTAL FLOOD                  3.0
#       DUST DEVIL                     0.0
#       EXCESSIVE HEAT                 1.0
#       EXTREME COLD                   2.0
#       EXTREME WINDCHILL              1.0
#       FLASH FLOOD                    0.0
#       FLOOD                          3.0
#       FREEZE                         0.0
#       HAIL                           0.0
#       HEAVY RAIN                     0.0
#       HEAVY SNOW                     4.0
#       HEAVY SNOW/WIND                0.0
#       HIGH SEAS                      1.0
#       HIGH SURF                      0.0
#       HIGH TIDES                     0.0
#       HIGH WIND                      0.0
#       HIGH WIND/SEAS                 4.0
#       HIGH WINDS                     0.0
# ...
